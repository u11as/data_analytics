# %% [markdown]
# <a href="https://colab.research.google.com/github/u11as/data_analytics/blob/main/project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
df=pd.read_csv('/content/raw data.csv')
df.head()
# Out:
#    student_id  age  gender             major  study_hours_per_day  \
# 0      100000   26    Male  Computer Science             7.645367
# 1      100001   26    Male              Arts             5.700000
# 2      100002   17    Male              Arts             2.400000
# 3      100003   27   Other        Psychology             3.400000
# 4      100004   25  Female          Business             4.700000
#
#    social_media_hours  netflix_hours part_time_job  attendance_percentage  \
# 0                 3.0            0.1           Yes                   70.3
# 1                 0.5            0.4            No                   88.4
# 2                 4.2            0.7            No                   82.1
# 3                 4.6            2.3           Yes                   79.3
# 4                 0.8            2.7           Yes                   62.9
#
#    sleep_hours  ... screen_time  study_environment access_to_tutoring  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     80000 non-null  int64
#  1   age                            80000 non-null  int64
#  2   gender                         80000 non-null  object
#  3   major                          80000 non-null  object
#  4   study_hours_per_day            80000 non-null  float64
#  5   social_media_hours             80000 non-null  float64
#  6   netflix_hours                  80000 non-null  float64
#  7   part_time_job                  80000 non-null  object
#  8   attendance_percentage          80000 non-null  float64
#  9   sleep_hours                    80000 non-null  float64
#  10  diet_quality                   80000 non-null  object
#  11  exercise_frequency             80000 non-null  int64
# ...

# %%
df.shape
# Out:
# (80000, 31)

# %%
df.describe()
# Out:
#           student_id           age  study_hours_per_day  social_media_hours  \
# count   80000.000000  80000.000000         80000.000000        80000.000000
# mean   139999.500000     22.004262             4.174388            2.501366
# std     23094.155105      3.745537             2.004135            1.445441
# min    100000.000000     16.000000             0.000000            0.000000
# 25%    119999.750000     19.000000             2.800000            1.200000
# 50%    139999.500000     22.000000             4.125624            2.500000
# 75%    159999.250000     25.000000             5.500000            3.800000
# max    179999.000000     28.000000            12.000000            5.000000
#
#        netflix_hours  attendance_percentage   sleep_hours  exercise_frequency  \
# count   80000.000000           80000.000000  80000.000000        80000.000000
# mean        1.997754              69.967884      7.017417            3.516587
# ...

# %%
df.drop(['study_hours_per_day','social_media_hours','social_media_hours','sleep_hours','exercise_frequency','mental_health_rating','stress_level','stress_level'],axis=1,inplace=True)
df.head()
# Out:
#    student_id  age  gender             major  netflix_hours part_time_job  \
# 0      100000   26    Male  Computer Science            0.1           Yes
# 1      100001   26    Male              Arts            0.4            No
# 2      100002   17    Male              Arts            0.7            No
# 3      100003   27   Other        Psychology            2.3           Yes
# 4      100004   25  Female          Business            2.7           Yes
#
#    attendance_percentage diet_quality parental_education_level  \
# 0                   70.3         Poor             Some College
# 1                   88.4         Good                      PhD
# 2                   82.1         Good              High School
# 3                   79.3         Fair                   Master
# 4                   62.9         Good                      PhD
#
#   internet_quality  ... screen_time  study_environment  access_to_tutoring  \
# ...

# %%
df.shape
# Out:
# (80000, 25)

# %%
df.drop(['netflix_hours','part_time_job','diet_quality','internet_quality','screen_time','study_environment','access_to_tutoring','family_income_range'],axis=1,inplace=True)
df.head()
# Out:
#    student_id  age  gender             major  attendance_percentage  \
# 0      100000   26    Male  Computer Science                   70.3
# 1      100001   26    Male              Arts                   88.4
# 2      100002   17    Male              Arts                   82.1
# 3      100003   27   Other        Psychology                   79.3
# 4      100004   25  Female          Business                   62.9
#
#   parental_education_level extracurricular_participation  previous_gpa  \
# 0             Some College                           Yes          4.00
# 1                      PhD                            No          4.00
# 2              High School                           Yes          3.79
# 3                   Master                           Yes          4.00
# 4                      PhD                            No          4.00
#
#    semester dropout_risk  social_activity  parental_support_level  \
# ...

# %%
df.drop(['parental_support_level','motivation_level','exam_anxiety_score','learning_style','time_management_score'],axis=1,inplace=True)
df.head()
# Out:
#    student_id  age  gender             major  attendance_percentage  \
# 0      100000   26    Male  Computer Science                   70.3
# 1      100001   26    Male              Arts                   88.4
# 2      100002   17    Male              Arts                   82.1
# 3      100003   27   Other        Psychology                   79.3
# 4      100004   25  Female          Business                   62.9
#
#   parental_education_level extracurricular_participation  previous_gpa  \
# 0             Some College                           Yes          4.00
# 1                      PhD                            No          4.00
# 2              High School                           Yes          3.79
# 3                   Master                           Yes          4.00
# 4                      PhD                            No          4.00
#
#    semester dropout_risk  social_activity  exam_score
# 0         5           No                0         100
# ...

# %%
df.shape
# Out:
# (80000, 12)

# %%
df['major'].unique()
# Out:
# array(['Computer Science', 'Arts', 'Psychology', 'Business',
#        'Engineering', 'Biology'], dtype=object)

# %%
df.nunique()
# Out:
# student_id                       80000
# age                                 13
# gender                               3
# major                                6
# attendance_percentage              601
# parental_education_level             5
# extracurricular_participation        2
# previous_gpa                       220
# semester                             8
# dropout_risk                         2
# social_activity                      6
# exam_score                          65
# dtype: int64
